# %% [markdown]
# In this notebook, we will build a 3D map of a scene from a small set of images and then localize an image downloaded from the Internet. This demo was contributed by [Philipp Lindenberger](https://github.com/Phil26AT/).

# %%
# %load_ext autoreload
# %autoreload 2
import tqdm, tqdm.notebook

tqdm.tqdm = tqdm.notebook.tqdm  # notebook-friendly progress bars
from pathlib import Path
import numpy as np

from hloc import (
    extract_features,
    match_features,
    reconstruction,
    visualization,
    pairs_from_exhaustive,
)
from hloc.visualization import plot_images, read_image
from hloc.utils import viz_3d

# %% [markdown]
# # Setup
# Here we define some output paths.

# %%
images = Path.home() / "data/C4_RO_Aisles/Aisle19_01_sub"
outputs = images / "demo_output"
outputs.mkdir(exist_ok=True, parents=True)
# !rm -rf $outputs
sfm_pairs = outputs / "pairs-sfm.txt"
loc_pairs = outputs / "pairs-loc.txt"
sfm_dir = outputs / "sfm"
features = outputs / "features.h5"
matches = outputs / "matches.h5"

feature_conf = extract_features.confs["disk"]
matcher_conf = match_features.confs["disk+lightglue"]

# %% [markdown]
# # 3D mapping
# First we list the images used for mapping. These are all day-time shots of Sacre Coeur.

# %%
from hloc_run.localized_image import get_image_files

references = get_image_files(images)
references = [p.relative_to(images).as_posix() for p in references]
print(f"Found {len(references)} images in {images}")
# Out:
# Found 20 images in /home/john/data/C4_RO_Aisles/Aisle19_01_sub

# %% [markdown]
# Then we extract features and match them across image pairs. Since we deal with few images, we simply match all pairs exhaustively. For larger scenes, we would use image retrieval, as demonstrated in the other notebooks.

# %%
extract_features.main(
    feature_conf, images, image_list=references, feature_path=features
)
pairs_from_exhaustive.main(sfm_pairs, image_list=references)
match_features.main(matcher_conf, sfm_pairs, features=features, matches=matches);
# Out:
# [2025/06/11 14:04:45 hloc INFO] Extracting local features with configuration:
# {'model': {'max_keypoints': 5000, 'name': 'disk'},
#  'output': 'feats-disk',
#  'preprocessing': {'grayscale': False, 'resize_max': 1600}}
#   0%|          | 0/20 [00:00<?, ?it/s]
# [2025/06/11 14:04:52 hloc INFO] Finished exporting features.
# [2025/06/11 14:04:52 hloc INFO] Found 190 pairs.
# [2025/06/11 14:04:52 hloc INFO] Matching local features with configuration:
# {'model': {'features': 'disk', 'name': 'lightglue'},
#  'output': 'matches-disk-lightglue'}
# /home/john/dev/hloc_run/.venv/lib/python3.12/site-packages/lightglue/lightglue.py:24: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
#   0%|          | 0/190 [00:00<?, ?it/s]
# [2025/06/11 14:05:01 hloc INFO] Finished exporting matches.

# %% [markdown]
# The we run incremental Structure-From-Motion and display the reconstructed 3D model.

# %%
model = reconstruction.main(
    sfm_dir, images, sfm_pairs, features, matches, image_list=references
)
fig = viz_3d.init_figure()
viz_3d.plot_reconstruction(
    fig, model, color="rgba(255,0,0,0.5)", name="mapping", points_rgb=True
)
fig.show()
# Out:
# [2025/06/11 14:05:04 hloc INFO] Creating an empty database...
# [2025/06/11 14:05:04 hloc INFO] Importing images into the database...
# [2025/06/11 14:05:05 hloc INFO] Importing features into the database...
#   0%|          | 0/20 [00:00<?, ?it/s]
# [2025/06/11 14:05:05 hloc INFO] Importing matches into the database...
#   0%|          | 0/190 [00:00<?, ?it/s]
# [2025/06/11 14:05:05 hloc INFO] Performing geometric verification of the matches...
# I20250611 14:05:05.299658 139735091570368 misc.cc:44]
# ==============================================================================
# Feature matching
# ==============================================================================
139741379053376 incremental_pipeline.cc:404] => Could not register, trying another image.
# I20250611 14:05:15.741289 139741379053376 incremental_pipeline.cc:390] Registering image #6 (5)
# I20250611 14:05:15.741291 139741379053376 incremental_pipeline.cc:393] => Image sees 468 / 4919 points
# I20250611 14:05:15.741486 139741379053376 incremental_pipeline.cc:404] => Could not register, trying another image.
# I20250611 14:05:15.741489 139741379053376 incremental_pipeline.cc:390] Registering image #7 (5)
# I20250611 14:05:15.741491 139741379053376 incremental_pipeline.cc:393] => Image sees 501 / 4830 points
# I20250611 14:05:15.741682 139741379053376 incremental_pipeline.cc:404] => Could not register, trying another image.
# I20250611 14:05:15.742639 139741379053376 incremental_pipeline.cc:282] Finding good initial image pair
# I20250611 14:05:16.620726 139741379053376 incremental_pipeline.cc:306] Initializing with image pair #9 and #2
# I20250611 14:05:16.621849 139741379053376 incremental_pipeline.cc:311] Global bundle adjustment
# I20250611 14:05:16.754768 139741379053376 incremental_pipeline.cc:390] Registering image #8 (3)
# I20250611 14:05:16.754780 139741379053376 incremental_pipeline.cc:393] => Image sees 353 / 4657 points
# I20250611 14:05:17.087706 139741379053376 incremental_pipeline.cc:42] Retriangulation and Global bundle adjustment
# I20250611 14:05:17.604211 139741379053376 incremental_pipeline.cc:390] Registering image #7 (4)
# I20250611 14:05:17.604229 139741379053376 incremental_pipeline.cc:393] => Image sees 1344 / 4830 points
# I20250611 14:05:18.067429 139741379053376 incremental_pipeline.cc:42] Retriangulation and Global bundle adjustment
# I20250611 14:05:18.776480 139741379053376 incremental_pipeline.cc:390] Registering image #3 (5)
# I20250611 14:05:18.776496 139741379053376 incremental_pipeline.cc:393] => Image sees 1302 / 4808 points
# I20250611 14:05:18.776703 139741379053376 incremental_pipeline.cc:404] => Could not register, trying another image.
# I20250611 14:05:18.776705 139741379053376 incremental_pipeline.cc:390] Registering image #5 (5)
# I20250611 14:05:18.776707 139741379053376 incremental_pipeline.cc:393] => Image sees 1277 / 4898 points
# I20250611 14:05:18.776916 139741379053376 incremental_pipeline.cc:404] => Could not register, trying another image.
# I20250611 14:05:18.776918 139741379053376 incremental_pipeline.cc:390] Registering image #6 (5)
# I20250611 14:05:18.776920 139741379053376 incremental_pipeline.cc:393] => Image sees 1307 / 4919 points
# I20250611 14:05:18.777140 139741379053376 incremental_pipeline.cc:404] => Could not register, trying another image.
# I20250611 14:05:18.777142 139741379053376 incremental_pipeline.cc:390] Registering image #4 (5)
# I20250611 14:05:18.777144 139741379053376 incremental_pipeline.cc:393] => Image sees 1254 / 4867 points
# I20250611 14:05:18.777341 139741379053376 incremental_pipeline.cc:404] => Could not register, trying another image.
# I20250611 14:05:18.777343 139741379053376 incremental_pipeline.cc:390] Registering image #1 (5)
# I20250611 14:05:18.777344 139741379053376 incremental_pipeline.cc:393] => Image sees 876 / 4422 points
# I20250611 14:05:18.777502 139741379053376 incremental_pipeline.cc:404] => Could not register, trying another image.
# I20250611 14:05:18.777505 139741379053376 incremental_pipeline.cc:42] Retriangulation and Global bundle adjustment
# I20250611 14:05:18.788882 139741379053376 incremental_pipeline.cc:390] Registering image #3 (5)
# I20250611 14:05:18.788886 139741379053376 incremental_pipeline.cc:393] => Image sees 1302 / 4808 points
# I20250611 14:05:18.789069 139741379053376 incremental_pipeline.cc:404] => Could not register, trying another image.
# I20250611 14:05:18.789071 139741379053376 incremental_pipeline.cc:390] Registering image #5 (5)
# I20250611 14:05:18.789073 139741379053376 incremental_pipeline.cc:393] => Image sees 1277 / 4898 points
# I20250611 14:05:18.789280 139741379053376 incremental_pipeline.cc:404] => Could not register, trying another image.
# I20250611 14:05:18.789284 139741379053376 incremental_pipeline.cc:390] Registering image #6 (5)
# I20250611 14:05:18.789286 139741379053376 incremental_pipeline.cc:393] => Image sees 1307 / 4919 points
# I20250611 14:05:18.789495 139741379053376 incremental_pipeline.cc:404] => Could not register, trying another image.
# I20250611 14:05:18.789498 139741379053376 incremental_pipeline.cc:390] Registering image #4 (5)
# I20250611 14:05:18.789499 139741379053376 incremental_pipeline.cc:393] => Image sees 1254 / 4867 points
# I20250611 14:05:18.789689 139741379053376 incremental_pipeline.cc:404] => Could not register, trying another image.
# I20250611 14:05:18.789691 139741379053376 incremental_pipeline.cc:390] Registering image #1 (5)
# I20250611 14:05:18.789693 139741379053376 incremental_pipeline.cc:393] => Image sees 876 / 4422 points
# I20250611 14:05:18.789847 139741379053376 incremental_pipeline.cc:404] => Could not register, trying another image.
# I20250611 14:05:18.790702 139741379053376 incremental_pipeline.cc:282] Finding good initial image pair
# I20250611 14:05:18.794701 139741379053376 incremental_pipeline.cc:306] Initializing with image pair #9 and #1
# I20250611 14:05:18.795034 139741379053376 incremental_pipeline.cc:311] Global bundle adjustment
# I20250611 14:05:18.842186 139741379053376 incremental_pipeline.cc:390] Registering image #8 (3)
# I20250611 14:05:18.842193 139741379053376 incremental_pipeline.cc:393] => Image sees 102 / 4657 points
# I20250611 14:05:19.079182 139741379053376 incremental_pipeline.cc:42] Retriangulation and Global bundle adjustment
# I20250611 14:05:19.977626 139741379053376 incremental_pipeline.cc:390] Registering image #7 (4)
# I20250611 14:05:19.977642 139741379053376 incremental_pipeline.cc:393] => Image sees 1689 / 4830 points
# I20250611 14:05:21.282285 139741379053376 incremental_pipeline.cc:42] Retriangulation and Global bundle adjustment
# I20250611 14:05:22.716087 139741379053376 incremental_pipeline.cc:390] Registering image #6 (5)
# I20250611 14:05:22.716111 139741379053376 incremental_pipeline.cc:393] => Image sees 3617 / 4919 points
# I20250611 14:05:24.181069 139741379053376 incremental_pipeline.cc:42] Retriangulation and Global bundle adjustment
# I20250611 14:05:24.641431 139741379053376 incremental_pipeline.cc:390] Registering image #5 (6)
# I20250611 14:05:24.641455 139741379053376 incremental_pipeline.cc:393] => Image sees 3761 / 4898 points
# I20250611 14:05:26.590880 139741379053376 incremental_pipeline.cc:42] Retriangulation and Global bundle adjustment
# I20250611 14:05:28.833533 139741379053376 incremental_pipeline.cc:390] Registering image #4 (7)
# I20250611 14:05:28.833558 139741379053376 incremental_pipeline.cc:393] => Image sees 3510 / 4867 points
# I20250611 14:05:29.971757 139741379053376 incremental_pipeline.cc:42] Retriangulation and Global bundle adjustment
# I20250611 14:05:31.282420 139741379053376 incremental_pipeline.cc:390] Registering image #3 (8)
# I20250611 14:05:31.282443 139741379053376 incremental_pipeline.cc:393] => Image sees 3790 / 4808 points
# I20250611 14:05:32.078961 139741379053376 incremental_pipeline.cc:42] Retriangulation and Global bundle adjustment
# I20250611 14:05:33.512553 139741379053376 incremental_pipeline.cc:390] Registering image #2 (9)
# I20250611 14:05:33.512576 139741379053376 incremental_pipeline.cc:393] => Image sees 3566 / 4742 points
# I20250611 14:05:34.162287 139741379053376 incremental_pipeline.cc:42] Retriangulation and Global bundle adjustment
# I20250611 14:05:35.100182 139741379053376 incremental_pipeline.cc:390] Registering image #10 (10)
# I20250611 14:05:35.100203 139741379053376 incremental_pipeline.cc:393] => Image sees 204 / 4789 points
# I20250611 14:05:35.654300 139741379053376 incremental_pipeline.cc:42] Retriangulation and Global bundle adjustment
# I20250611 14:05:36.730169 139741379053376 incremental_pipeline.cc:390] Registering image #20 (11)
# I20250611 14:05:36.730191 139741379053376 incremental_pipeline.cc:393] => Image sees 209 / 4706 points
# I20250611 14:05:37.619982 139741379053376 incremental_pipeline.cc:42] Retriangulation and Global bundle adjustment
# I20250611 14:05:39.608059 139741379053376 incremental_pipeline.cc:390] Registering image #19 (12)
# I20250611 14:05:39.608081 139741379053376 incremental_pipeline.cc:393] => Image sees 2677 / 4807 points
# I20250611 14:05:40.269979 139741379053376 incremental_pipeline.cc:42] Retriangulation and Global bundle adjustment
# I20250611 14:05:40.969340 139741379053376 incremental_pipeline.cc:390] Registering image #18 (13)
# I20250611 14:05:40.969361 139741379053376 incremental_pipeline.cc:393] => Image sees 3336 / 4763 points
# I20250611 14:05:41.440912 139741379053376 incremental_pipeline.cc:390] Registering image #11 (14)
# I20250611 14:05:41.440942 139741379053376 incremental_pipeline.cc:393] => Image sees 3558 / 4854 points
# I20250611 14:05:42.139161 139741379053376 incremental_pipeline.cc:42] Retriangulation and Global bundle adjustment
# I20250611 14:05:42.897495 139741379053376 incremental_pipeline.cc:390] Registering image #17 (15)
# I20250611 14:05:42.897520 139741379053376 incremental_pipeline.cc:393] => Image sees 3649 / 4778 points
# I20250611 14:05:43.456765 139741379053376 incremental_pipeline.cc:390] Registering image #16 (16)
# I20250611 14:05:43.456788 139741379053376 incremental_pipeline.cc:393] => Image sees 2946 / 4706 points
# I20250611 14:05:44.326846 139741379053376 incremental_pipeline.cc:42] Retriangulation and Global bundle adjustment
# I20250611 14:05:45.695624 139741379053376 incremental_pipeline.cc:390] Registering image #12 (17)
# I20250611 14:05:45.695647 139741379053376 incremental_pipeline.cc:393] => Image sees 3511 / 4799 points
# I20250611 14:05:46.383589 139741379053376 incremental_pipeline.cc:390] Registering image #13 (18)
# I20250611 14:05:46.383611 139741379053376 incremental_pipeline.cc:393] => Image sees 3542 / 4868 points
# I20250611 14:05:47.351111 139741379053376 incremental_pipeline.cc:42] Retriangulation and Global bundle adjustment
# I20250611 14:05:48.410201 139741379053376 incremental_pipeline.cc:390] Registering image #14 (19)
# I20250611 14:05:48.410225 139741379053376 incremental_pipeline.cc:393] => Image sees 3479 / 4663 points
# I20250611 14:05:49.278177 139741379053376 incremental_pipeline.cc:390] Registering image #15 (20)
# I20250611 14:05:49.278202 139741379053376 incremental_pipeline.cc:393] => Image sees 3604 / 4540 points
# I20250611 14:05:49.999035 139741379053376 incremental_pipeline.cc:42] Retriangulation and Global bundle adjustment
# I20250611 14:05:52.214822 139741379053376 timer.cc:91] Elapsed time: 0.779 [minutes]
# [2025/06/11 14:05:52 hloc INFO] Reconstructed 2 model(s).
# [2025/06/11 14:05:52 hloc INFO] Largest model is #1 with 20 images.
# [2025/06/11 14:05:52 hloc INFO] Reconstruction statistics:
# Reconstruction:
# 	num_cameras = 20
# 	num_images = 20
# 	num_reg_images = 20
# 	num_points3D = 12819
# 	num_observations = 80591
# 	mean_track_length = 6.28684
# 	mean_observations_per_image = 4029.55
# 	mean_reprojection_error = 1.1449
# 	num_input_images = 20

# %% [markdown]
# We also visualize which keypoints were triangulated into the 3D model.

# %% [markdown]
# # Localization
# Now that we have a 3D map of the scene, we can localize any image. To demonstrate this, we download [a night-time image from Wikimedia](https://commons.wikimedia.org/wiki/File:Paris_-_Basilique_du_Sacr%C3%A9_Coeur,_Montmartre_-_panoramio.jpg).

# %%
url = "https://upload.wikimedia.org/wikipedia/commons/5/53/Paris_-_Basilique_du_Sacr%C3%A9_Coeur%2C_Montmartre_-_panoramio.jpg"
# try other queries by uncommenting their url
# url = "https://upload.wikimedia.org/wikipedia/commons/5/59/Basilique_du_Sacr%C3%A9-C%C5%93ur_%285430392880%29.jpg"
# url = "https://upload.wikimedia.org/wikipedia/commons/8/8e/Sacr%C3%A9_C%C5%93ur_at_night%21_%285865355326%29.jpg"
query = "query/night.jpg"
# !mkdir -p $images/query && wget $url -O $images/$query -q
plot_images([read_image(images / query)], dpi=75)

# %% [markdown]
# Again, we extract features for the query and match them exhaustively.

# %%
extract_features.main(
    feature_conf, images, image_list=[query], feature_path=features, overwrite=True
)
pairs_from_exhaustive.main(loc_pairs, image_list=[query], ref_list=references)
match_features.main(
    matcher_conf, loc_pairs, features=features, matches=matches, overwrite=True
);
# Out:
# [2023/07/11 16:43:29 hloc INFO] Extracting local features with configuration:
# {'model': {'max_keypoints': 5000, 'name': 'disk'},
#  'output': 'feats-disk',
#  'preprocessing': {'grayscale': False, 'resize_max': 1600}}
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  2.44it/s]
# [2023/07/11 16:43:29 hloc INFO] Finished exporting features.
# [2023/07/11 16:43:29 hloc INFO] Found 10 pairs.
# [2023/07/11 16:43:29 hloc INFO] Matching local features with configuration:
# {'model': {'features': 'disk', 'name': 'lightglue'},
#  'output': 'matches-disk-lightglue'}
# Loaded LightGlue model
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 11.45it/s]
# [2023/07/11 16:43:30 hloc INFO] Finished exporting matches.

# %% [markdown]
# We read the EXIF data of the query to infer a rough initial estimate of camera parameters like the focal length. Then we estimate the absolute camera pose using PnP+RANSAC and refine the camera parameters.

# %%
import pycolmap
from hloc.localize_sfm import QueryLocalizer, pose_from_cluster

camera = pycolmap.infer_camera_from_image(images / query)
ref_ids = [model.find_image_with_name(r).image_id for r in references]
conf = {
    "estimation": {"ransac": {"max_error": 12}},
    "refinement": {"refine_focal_length": True, "refine_extra_params": True},
}
localizer = QueryLocalizer(model, conf)
ret, log = pose_from_cluster(localizer, query, camera, ref_ids, features, matches)

print(f'found {ret["num_inliers"]}/{len(ret["inliers"])} inlier correspondences.')
visualization.visualize_loc_from_log(images, query, log, model)
# Out:
# found 3156/4665 inlier correspondences.

# %% [markdown]
# We visualize the correspondences between the query images a few mapping images. We can also visualize the estimated camera pose in the 3D map.

# %%
pose = pycolmap.Image(cam_from_world=ret["cam_from_world"])
viz_3d.plot_camera_colmap(
    fig, pose, camera, color="rgba(0,255,0,0.5)", name=query, fill=True
)
# visualize 2D-3D correspodences
inl_3d = np.array(
    [model.points3D[pid].xyz for pid in np.array(log["points3D_ids"])[ret["inliers"]]]
)
viz_3d.plot_points(fig, inl_3d, color="lime", ps=1, name=query)
fig.show()
